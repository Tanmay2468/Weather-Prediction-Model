# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("weathernew.csv", index_col= "DATE")

# %%
data.head()
# Out:
#                 STATION                              NAME  ACMH   ACSH  AWND  \
# DATE
# 01-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0   NaN
# 02-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0   NaN
# 03-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0   NaN
# 04-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0   NaN
# 05-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0   NaN
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT11  WT13  WT14  WT15  WT16  \
# DATE                                      ...
# 01-01-1970   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 02-01-1970   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 03-01-1970   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   NaN   1.0
# 04-01-1970   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# ...

# %%
data.describe()
# Out:
#               ACMH         ACSH          AWND          FMTM          PGTM  \
# count  9615.000000  9616.000000  14171.000000  10124.000000  12269.000000
# mean     57.886635    60.665557     11.234329   1438.505828   1383.805852
# std      30.612050    33.353307      4.791638    758.281872    631.437135
# min       0.000000     0.000000      0.220000      0.000000      0.000000
# 25%      30.000000    30.000000      8.280000   1101.750000   1023.000000
# 50%      60.000000    70.000000     10.510000   1526.000000   1458.000000
# 75%      80.000000    90.000000     13.420000   1850.000000   1837.000000
# max     100.000000   100.000000    308.030000  32767.000000   2359.000000
#
#                PRCP          SNOW          SNWD         TAVG          TMAX  \
# count  19287.000000  19287.000000  19285.000000  6164.000000  19287.000000
# mean       0.117869      0.064671      0.209645    55.554672     61.820086
# std        0.330974      0.598955      1.272844    16.566519     17.410481
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
# To remove the null value 
null_pct = data.apply(pd.isnull).sum()/data.shape[0]

# %%
# here we used the pandas dataframe function were A DataFrame is a two-dimensional, size-mutable, and labeled data structure in pandas, which is a powerful data manipulation and analysis library for Python
data.apply(pd.isnull).sum()
# Out:
# STATION        0
# NAME           0
# ACMH        9672
# ACSH        9671
# AWND        5116
# FMTM        9163
# PGTM        7018
# PRCP           0
# SNOW           0
# SNWD           2
# TAVG       13123
# TMAX           0
# TMIN           0
# TSUN       19256
# WDF1        9676
# WDF2        9618
# WDF5        9701
# WDFG       14166
# WDFM       19286
# WESD       13216
# WSF1        9673
# WSF2        9618
# WSF5        9702
# WSFG       11824
# WSFM       19286
# WT01       12155
# WT02       18034
# WT03       18000
# WT04       18951
# WT05       18923
# WT06       19106
# WT07       19179
# WT08       15371
# WT09       19147
# WT11       19273
# WT13       17102
# WT14       18400
# WT15       19245
# WT16       12710
# WT17       19227
# WT18       18120
# WT21       19282
# WT22       19238
# WV01       19286
# dtype: int64

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.501478
# ACSH       0.501426
# AWND       0.265256
# FMTM       0.475087
# PGTM       0.363872
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000104
# TAVG       0.680406
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998393
# WDF1       0.501685
# WDF2       0.498678
# WDF5       0.502981
# WDFG       0.734484
# WDFM       0.999948
# WESD       0.685228
# WSF1       0.501530
# WSF2       0.498678
# WSF5       0.503033
# WSFG       0.613055
# WSFM       0.999948
# WT01       0.630217
# WT02       0.935034
# WT03       0.933271
# WT04       0.982579
# WT05       0.981127
# WT06       0.990615
# WT07       0.994400
# WT08       0.796962
# WT09       0.992741
# WT11       0.999274
# WT13       0.886711
# WT14       0.954010
# WT15       0.997822
# WT16       0.658993
# WT17       0.996889
# WT18       0.939493
# WT21       0.999741
# WT22       0.997459
# WV01       0.999948
# dtype: float64

# %%
# now, inorder to remove the null values from the dataset 


valid_values = data.columns[null_pct<.05]

# %%
valid_values
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
print(data.columns)
# Out:
# Index(['STATION', 'NAME', 'ACMH', 'ACSH', 'AWND', 'FMTM', 'PGTM', 'PRCP',
#        'SNOW', 'SNWD', 'TAVG', 'TMAX', 'TMIN', 'TSUN', 'WDF1', 'WDF2', 'WDF5',
#        'WDFG', 'WDFM', 'WESD', 'WSF1', 'WSF2', 'WSF5', 'WSFG', 'WSFM', 'WT01',
#        'WT02', 'WT03', 'WT04', 'WT05', 'WT06', 'WT07', 'WT08', 'WT09', 'WT11',
#        'WT13', 'WT14', 'WT15', 'WT16', 'WT17', 'WT18', 'WT21', 'WT22', 'WV01'],
#       dtype='object')

# %%
# now for ease of usage we can convert the columns names in block letter to small letters
#valid_values = valid_values.str.lower()

# %%
valid_values
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
data = data[valid_values].copy()

# %%
data
# Out:
#                 STATION                              NAME  PRCP  SNOW  SNWD  \
# DATE
# 01-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 02-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 03-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 04-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 05-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 17-10-2022  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 18-10-2022  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 19-10-2022  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 20-10-2022  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 21-10-2022  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             TMAX  TMIN
# DATE
# ...

# %%
data.columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
data.columns = data.columns.str.lower()

# %%
data.columns
# Out:
# Index(['station', 'name', 'prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
data = data.ffill()

# %%
data.columns
# Out:
# Index(['station', 'name', 'prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
data.describe()
# Out:
#                prcp          snow          snwd          tmax          tmin
# count  19287.000000  19287.000000  19287.000000  19287.000000  19287.000000
# mean       0.117869      0.064671      0.209623     61.820086     47.535283
# std        0.330974      0.598955      1.272779     17.410481     16.418437
# min        0.000000      0.000000      0.000000      8.000000     -2.000000
# 25%        0.000000      0.000000      0.000000     48.000000     35.000000
# 50%        0.000000      0.000000      0.000000     62.000000     48.000000
# 75%        0.040000      0.000000      0.000000     77.000000     62.000000
# max        7.800000     30.300000     28.000000    103.000000     82.000000

# %%
data['snwd'].plot(color='r')
# Out:
# <Axes: xlabel='DATE'>

# %%
data.index
# Out:
# Index(['01-01-1970', '02-01-1970', '03-01-1970', '04-01-1970', '05-01-1970',
#        '06-01-1970', '07-01-1970', '08-01-1970', '09-01-1970', '10-01-1970',
#        ...
#        '12-10-2022', '13-10-2022', '14-10-2022', '15-10-2022', '16-10-2022',
#        '17-10-2022', '18-10-2022', '19-10-2022', '20-10-2022', '21-10-2022'],
#       dtype='object', name='DATE', length=19287)

# %%
data.index = pd.to_datetime(data.index, format="%d-%m-%Y")

# %%
data = data[~data.index.duplicated(keep='first')]
data = data.sort_index()

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    month_avg_col = data[col].groupby(data.index.month).apply(expand_mean)
    month_avg_col.index = data.index  # Set the index to match the DataFrame
    data[f"month_avg_{col}"] = month_avg_col

    day_avg_col = data[col].groupby(data.index.day_of_year).apply(expand_mean)
    day_avg_col.index = data.index  # Set the index to match the DataFrame
    data[f"day_avg_{col}"] = day_avg_col

# %%
#here its showing month day year whereas in default pd.to_datetime it assumes d-m-y

# %%
#now setup the target column, here we can use the shift operator

data["target"] = data.shift(-1)["tmax"]

# %%
data
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
data = data.ffill()

# %%
data
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import Ridge

# %%
rr= Ridge(alpha = .1)

# %%
predictors = data.columns[~data.columns.isin(["target","name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
def backtest(data, model, predictors, start=3650, step=90):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[:i,:]
        test = data.iloc[i:(i+step),:]

        model.fit(train[predictors], train["target"])

        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()

        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(data,rr, predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.163124   7.163124
# 1979-12-31    42.0   43.600541   1.600541
# 1980-01-01    41.0   41.503351   0.503351
# 1980-01-02    36.0   43.853752   7.853752
# 1980-01-03    30.0   40.145222  10.145222
# ...            ...         ...        ...
# 2022-10-17    58.0   67.403986   9.403986
# 2022-10-18    56.0   60.364590   4.364590
# 2022-10-19    61.0   56.879203   4.120797
# 2022-10-20    64.0   59.642462   4.357538
# 2022-10-21    64.0   60.475790   3.524210
#
# [15637 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 5.1459734387127956

# %%
predictions["diff"].mean()
# Out:
# 5.1459734387127956

# %%
def pct_diff(old,new):
  return (new-old)/old

def compute_rolling(data, horizon, col):
  label= f"rolling_{horizon}_{col}"
  data[label]=data[col].rolling(horizon).mean()
  data[f"{label}_pct"]= pct_diff(data[label],data[col])
  return data

rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(data, horizon, col)

# %%
data
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
data= data.iloc[14:,:]

# %%
data=data.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    data[f"month_avg_{col}"] = data[col].groupby(data.index.month, group_keys=False).apply(expand_mean)
    data[f"day_avg_{col}"] = data[col].groupby(data.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
data
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
predictors = data.columns[~data.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp', 'rolling_3_tmax', 'rolling_3_tmax_pct',
#        'rolling_3_tmin', 'rolling_3_tmin_pct', 'rolling_3_prcp',
#        'rolling_3_prcp_pct', 'rolling_14_tmax', 'rolling_14_tmax_pct',
#        'rolling_14_tmin', 'rolling_14_tmin_pct', 'rolling_14_prcp',
#        'rolling_14_prcp_pct'],
#       dtype='object')

# %%
predictions= backtest(data,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1980-01-13    54.0   32.407593  21.592407
# 1980-01-14    51.0   44.687775   6.312225
# 1980-01-15    45.0   46.850038   1.850038
# 1980-01-16    40.0   42.206425   2.206425
# 1980-01-17    41.0   40.838566   0.161434
# ...            ...         ...        ...
# 2022-10-17    58.0   67.305806   9.305806
# 2022-10-18    56.0   62.352717   6.352717
# 2022-10-19    61.0   59.699531   1.300469
# 2022-10-20    64.0   62.140106   1.859894
# 2022-10-21    64.0   63.123957   0.876043
#
# [15623 rows x 3 columns]

# %%
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 4.79251052713896

# %%
predictions.sort_values("diff",ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.361065  30.638935
# 2007-03-26    78.0   49.965413  28.034587
# 1998-03-26    80.0   51.966675  28.033325
# 2003-04-15    86.0   59.432179  26.567821
# 1985-04-18    84.0   58.425960  25.574040
# ...            ...         ...        ...
# 1987-09-16    75.0   75.001185   0.001185
# 1984-08-10    83.0   82.999179   0.000821
# 2011-09-25    78.0   77.999237   0.000763
# 1999-09-28    77.0   76.999245   0.000755
# 1984-12-24    47.0   46.999514   0.000486
#
# [15623 rows x 3 columns]

# %%
data.loc["1990-03-07":"1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
# ...

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>

# %%
mea=mean_absolute_error(predictions["actual"],predictions["prediction"])
percent_acc= 100* (1-mea/predictions["actual"].mean())

# %%
percent_acc
# Out:
# 92.27786145897232

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(predictions['actual'], predictions['prediction'])
# Mean Squared Error (MSE)
mse = mean_squared_error(predictions['actual'], predictions['prediction'])
# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
# Coefficient of Determination (R-squared)
r_squared = r2_score(predictions['actual'], predictions['prediction'])

# %%
# Mean Absolute Percentage Error (MAPE)
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
mape = mean_absolute_percentage_error(predictions['actual'], predictions['prediction'])

# %%
# Symmetric Mean Absolute Percentage Error (SMAPE)
def symmetric_mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred))) * 100
smape = symmetric_mean_absolute_percentage_error(predictions['actual'], predictions['prediction'])

# %%
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Coefficient of Determination (R-squared):", r_squared)
print("Mean Absolute Percentage Error (MAPE):", mape)
print("Symmetric Mean Absolute Percentage Error (SMAPE):", smape)
# Out:
# Mean Absolute Error (MAE): 4.79251052713896
# Mean Squared Error (MSE): 37.610747772757755
# Root Mean Squared Error (RMSE): 6.132760208320374
# Coefficient of Determination (R-squared): 0.8747016857483911
# Mean Absolute Percentage Error (MAPE): 8.899734160785982
# Symmetric Mean Absolute Percentage Error (SMAPE): 8.698442797740444

# %%
from sklearn.metrics import precision_score, f1_score, recall_score

# %%
cold_threshold = 10
hot_threshold = 30

# Binarize predictions and actual values based on thresholds
predictions_bin = (predictions['prediction'] >= hot_threshold).astype(int)  # Example: 1 if hot, 0 otherwise
actual_bin = (predictions['actual'] >= hot_threshold).astype(int)  # Example: 1 if hot, 0 otherwise

# Calculate precision, recall, and F1-score
precision = precision_score(actual_bin, predictions_bin)
recall = recall_score(actual_bin, predictions_bin)
f1 = f1_score(actual_bin, predictions_bin)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.9822573334196724
# Recall: 0.9952106022831649
# F1 Score: 0.9886915430992341
